# %% [markdown]
# # Needed Packages

# %%
#General imports
import os
import sys
import copy
import time
import fnmatch
import subprocess
import nglview as ngl
from invoke import run
from collections import Counter
from contextlib import redirect_stdout
from pathlib import Path
import math


#Mathematical imports
import numpy as np
from numpy import array, linspace
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt


#Import from ase
import ase
from ase import units
from ase import Atoms
from ase.io import read, write
from ase.units import Rydberg, Bohr
from ase.units import _amu
from ase.io.trajectory import Trajectory
from ase.build import bulk
from ase.build import surface
from ase.optimize import BFGS
from ase.visualize import view
from ase.filters import FrechetCellFilter
from ase.constraints import FixAtoms

from pyace import PyACECalculator

import elastic
from elastic import get_pressure, BMEOS, get_strain
from elastic import get_elementary_deformations, scan_volumes
from elastic import get_BM_EOS, get_elastic_tensor

from pymatgen.analysis.phase_diagram import PDEntry
from pymatgen.core.structure import Structure
from pymatgen.analysis.phase_diagram import PhaseDiagram
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.analysis.phase_diagram import PDPlotter
from pymatgen.io.ase import AseAtomsAdaptor
from mp_api.client import MPRester
from pymatgen.core import Structure
from pymatgen.core.surface import SlabGenerator

import phonopy

# %%
# %load_ext autoreload
# %autoreload 2
from pot_functions import *
from pw_functions import *
from phonon_functions import *
from frenkel import *
from point_defects import *
from rdf import *
from stacking_fault import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ref_energies = {
    'Li' : -14.221146 * Rydberg,
    'O' : -31.581697 * Rydberg,  
}


pot_path = '/ccc160/akirsan/PhD/MLP/Li2O/train/train-O2/train-O2-own/train-O2-own-1/kappa-1400/0.1'
pot_name = pot_path.replace("ccc160/akirsan/PhD/MLP/Li2O/train/", "")
analysis_path = os.path.join(pot_path, "analysis")
#run(f"mkdir {analysis_path}")
#strucs_all = pd.read_pickle(os.path.join(pot_path, "alldata.pckl.gzip"), compression="gzip")

calc = PyACECalculator(os.path.join(pot_path,"output_potential.yaml"))
calc.set_active_set((os.path.join(pot_path,"output_potential.asi")))
set_calculator(calc)

Ry_bohr3_to_GPa = 1.47108 *10 **4

# %% [markdown]
# # Create PW reference data

# %% [markdown]
# ## Sample input and PPs

# %%
input_data = {
                    'calculation' : 'scf',
                    'restart_mode' : 'from_scratch',
                    'pseudo_dir' : '/ccc160/bmeyer/pot.pwscf/',
                    'outdir' : './',
                    'prefix' : f"deform_{i}",
                    'tstress' : True,
                    'etot_conv_thr' : 1.e-5,
                    'tprnfor' : True,
                    'forc_conv_thr' : 1.e-5,
                    'ecutwfc' :30.0,
                    'ecutrho' :120.0,
                    'occupations' : 'smearing',
                    'mixing_mode' : 'plain',
                    'smearing' : 'gauss',
                    'degauss' : 0.01,
                    'vdw_corr' : 'D3-ext',
                    'london_rcut' : 100,
                    'diagonalization' : 'david',
                    'electron_maxstep' : 300,
                    'conv_thr' :1.0e-8,
                    'mixing_beta' : 0.5,
                    'kpts' : (8, 8, 4),
                    'koffset' : (0, 0, 0),
}
pseudopotentials = {
                    'Li' : 'Li-semi.uspp736-rev2.pbe.UPF',
                    'O' : 'O.uspp736.pbe.UPF'
}
# Out:
# a

# %% [markdown]
# ## PW reference dict (for output purposes only)

# %%
#in kJ/mol
ref_Ef = {
    'Li2O-solid' : -598.73,
    'Li2O2-solid' : -632.62,
}

# in eV per atom
#mol_ref_pw = { 'Li' : -14.357596 * Rydberg, #fcc
#               'O' : (-63.786020/2) * Rydberg }

element_refs = {
    'O':  ('O2', -63.786020* Rydberg),   # actual O2 molecule energy
    'Li': ('Li',  -14.357596 * Rydberg),  # actual bulk Li energy
}


#in GPa
ref_PBE_D3mod_elast = {
            'Li2O' : {
                'alat' : { 'a' : 4.6088},
                'elast_const' :{
                        'c11' : 204.35,
                        'c12' : 19.80,
                        'c44' : 58.21,
                        'c13' : 0,
                        'c33' : 0,
                        'B' : 81.32,
                        'G' : 71.83,
                        'E' : 166.49,
                        'v' : 0.158
                }
            },
            'Li2O2' : { 
                'alat' : { 'a' : 3.1432, 'c' : 7.6489 },
                'elast_const' :{
                        'c11' : 	 174.53,
                        'c33' :	     350.01,
                        'c12' : 	 48.03,
                        'c13' : 	 9.03,
                        'c44' : 	 40.94,
                        'B' : 	     87.69,
                        'G' : 0,
                        'E' : 0,
                        'v' : 0
                        }
                },
    
            'Li_bcc' : { 
                'alat' : { 'a' : 3.4254},
                'elast_const' :{
                        'c11' : 15.02,
                         'c12' : 13.45,
                         'c44' : 11.23,
                         'c33' : 0.00,
                         'c13' : 0.00,
                         'B' : 13.97,
                         'G' : 7.05,
                         'E' : 18.11,
                         'v' : 0.28
                },
            },
            'Li_fcc' : { 
                'alat' : { 'a' : 4.3053},
                'elast_const' :{
                        'c11' : 17.33,
                         'c12' : 13.37,
                         'c44' : 10.19,
                         'c33' : 0.00,
                         'c13' : 0.00,
                         'B' : 14.69,
                         'G' : 6.91,
                         'E' : 17.91,
                         'v' : 0.30
                       }
            }

}


ref_lit = {
    'Li2O2' : {
            'source' : 'https://doi.org/10.1080/14786430701286239',
            'method' : 'LDA',
            'alat' : { 'a' : 3.1817, 'c' : 7.6739 },
            'elast_const' : { 
                        'c11' : 207.3,
                        'c12' : 33.8,
                        'c13' : 21.5,
                        'c33' : 358.1,
                        'c44' : 46.4,
                        'B' : 98.0,
                        'G' : 0,
                        'E' : 0,
                        'v' : 0
                        },
                },
        'Li2O' : { 
            'source' : 'https://doi.org/10.1016/0022-3115(88)90039-6',
            'method' : 'Experiment_300K',
            'alat' : { 'a' : 4.611},
            'elast_const' : { 
                        'c11' : 202.0,
                        'c12' : 21.5,
                        'c13' : 0.0,
                        'c33' : 0.0,
                        'c44' : 58.7,
                        'B' : 81.7,
                        'G' : 71.3,
                        'E' : 165.7,
                        'v' : 0.162
                        },
                },
        'Li_bcc' : {
            'source' : 'https://doi.org/10.1016/j.commatsci.2022.111706 and https://doi.org/10.1063/1.1743926',
            'method' : 'Experiment_295K, B,G,E,v calculated from elast const',
            'alat' : { 'a' : 3.51},
            'elast_const' : { 
                        'c11' : 14.54,
                        'c12' : 12.52,
                        'c13' : 0.0,
                        'c33' : 0.0,
                        'c44' : 11.58,
                        'B' : 13.19,
                        'G' : 7.35,
                        'E' : 18.60,
                        'v' : 0.265
                        },
        },
        'Li_fcc' : {
            'source' : 'https://doi.org/10.1016/j.intermet.2010.06.015',
            'method' : 'PBE, v calculated from elast const',
            'alat' : { 'a' : 4.307},
            'elast_const' : { 
                        'c11' : 17.5,
                        'c12' : 11.4,
                        'c13' : 0.0,
                        'c33' : 0.0,
                        'c44' : 9.3,
                        'B' : 13.4,
                        'G' : 6.0,
                        'E' : 15.7,
                        'v' : 0.305
                        }
        }   
}

# for cubic crystals the elastic constants were calculated like this, if missing in the source
#B = (c11 + 2*c12) / 3 
#G = (c11_c12 + 3*c44) / 5
#E = 9*B*G / (3*B + G)
#v = 0.5*(3*B - 2*G)/(3*B + G)

# %%
#quantities = [name for name,key in ref_PBE_D3mod_elast.items()]
for name,key in ref_PBE_D3mod_elast.items():
    print(key)
# Out:
# {'alat': {'a': 4.6088}, 'elast_const': {'c11': 204.35, 'c12': 19.8, 'c44': 58.21, 'c13': 0, 'c33': 0, 'B': 81.32, 'G': 71.83, 'E': 166.49, 'v': 0.158}}
# {'alat': {'a': 3.1432, 'c': 7.6489}, 'elast_const': {'c11': 174.53, 'c33': 350.01, 'c12': 48.03, 'c13': 9.03, 'c44': 40.94, 'B': 87.69, 'G': 0, 'E': 0, 'v': 0}}
# {'alat': {'a': 3.4254}, 'elast_const': {'c11': 15.02, 'c12': 13.45, 'c44': 11.23, 'c33': 0.0, 'c13': 0.0, 'B': 13.97, 'G': 7.05, 'E': 18.11, 'v': 0.28}}
# {'alat': {'a': 4.3053}, 'elast_const': {'c11': 17.33, 'c12': 13.37, 'c44': 10.19, 'c33': 0.0, 'c13': 0.0, 'B': 14.69, 'G': 6.91, 'E': 17.91, 'v': 0.3}}

# %%
write_ref_comparison(ref_PBE_D3mod_elast, ref_lit, '/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/references.dat')

# %%
def write_ref_comparison(ref_PBE_D3mod, ref_lit, output_path):

    materials = [name for name,key in ref_PBE_D3mod_elast.items()]

    quantities = [
        'c11', 'c12', 'c13', 'c33', 'c44',
        'B', 'G', 'E', 'v'
    ]

    with open(output_path, 'w') as f:

        for material in materials:

            pbe = ref_PBE_D3mod[material]
            lit = ref_lit[material]

            pbe_alat = pbe.get('alat', {})
            lit_alat = lit.get('alat', {})

            pbe_elast = pbe.get('elast_const', {})
            lit_elast = lit.get('elast_const', {})

            # =========================================================
            # Material heading
            # =========================================================

            f.write(f"{material}\n")
            f.write("=" * len(material) + "\n\n")

            # =========================================================
            # Literature information
            # =========================================================

            method = lit.get('method', 'N/A')
            source = lit.get('source', 'N/A')

            f.write("Literature reference:\n")
            f.write(f"  Method: {method}\n")
            f.write(f"  Source: {source}\n\n")

            # =========================================================
            # Elastic constants + lattice constants
            # =========================================================

            f.write("Elastic constants [GPa]\n")
            f.write("-" * 62 + "\n")

            f.write(
                f"{'Value':<10}"
                f"{'Literature ref':<20}"
                f"{'PBE+D3mod':>14}\n"
            )

            f.write("-" * 62 + "\n")

            # Lattice constants first
            for lattice in ['a', 'c']:

                # Only print the row if it exists in either dictionary
                if lattice not in lit_alat and lattice not in pbe_alat:
                    continue

                lit_value = lit_alat.get(lattice)
                pbe_value = pbe_alat.get(lattice)

                lit_str = (
                    "---"
                    if lit_value is None
                    else f"{lit_value:.4f}"
                )

                pbe_str = (
                    "---"
                    if pbe_value is None
                    else f"{pbe_value:.4f}"
                )

                f.write(
                    f"{lattice + ' [Å]':<10}"
                    f"{lit_str:<20}"
                    f"{pbe_str:>14}\n"
                )

            # Elastic constants
            for quantity in quantities:

                lit_value = lit_elast.get(quantity)
                pbe_value = pbe_elast.get(quantity)

                lit_str = (
                    "---"
                    if lit_value is None
                    else f"{lit_value:.2f}"
                )

                pbe_str = (
                    "---"
                    if pbe_value is None
                    else f"{pbe_value:.2f}"
                )

                f.write(
                    f"{quantity:<10}"
                    f"{lit_str:<20}"
                    f"{pbe_str:>14}\n"
                )

            f.write("\n\n")

# %% [markdown]
# ## Create and Start PWSCF elastic deformation calculations

# %%
input_data = {
                    'calculation' : 'scf',
                    'restart_mode' : 'from_scratch',
                    'pseudo_dir' : '/ccc160/bmeyer/pot.pwscf/',
                    'outdir' : './',
                    'prefix' : f"deform",
                    'tstress' : True,
                    'etot_conv_thr' : 1.e-5,
                    'tprnfor' : True,
                    'forc_conv_thr' : 1.e-5,
                    'ecutwfc' :30.0,
                    'ecutrho' :120.0,
                    'occupations' : 'smearing',
                    'mixing_mode' : 'plain',
                    'smearing' : 'gauss',
                    'degauss' : 0.01,
                    'vdw_corr' : 'D3-ext',
                    'london_rcut' : 100,
                    'diagonalization' : 'david',
                    'electron_maxstep' : 300,
                    'conv_thr' :1.0e-8,
                    'mixing_beta' : 0.5,
                    'kpts' : (32, 32, 32),
                    'koffset' : (1, 1, 1),
}
pseudopotentials = {
                    'Li' : 'Li-semi.uspp736-rev2.pbe.UPF',
                    'O' : 'O.uspp736.pbe.UPF'
}    
calc_path = "/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li-metal/fcc/elastic"
runbatch_path = "/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/PW-templates/runbatch"
vdW_path = "/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li-metal/INP-vdW"

unstrained_atoms = read('/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li-metal/fcc/vc-relax/OUT', format='espresso-out')

deform_list = get_elementary_deformations(unstrained_atoms, n=6, d=3)

deform_dict = run_multiple_pw(deform_list, input_data, pseudopotentials, calc_path, runbatch_path, vdW_path)
atoms = read_pw_jobs(deform_dict)
# Out:
# Waiting for SLURM job 189913...
# SLURM job 189913 finished.
# Waiting for SLURM job 189914...
# SLURM job 189914 finished.
# Waiting for SLURM job 189915...
# SLURM job 189915 finished.
# Waiting for SLURM job 189916...
# SLURM job 189916 finished.
# Waiting for SLURM job 189917...
# SLURM job 189917 finished.
# Waiting for SLURM job 189918...
# SLURM job 189918 finished.
# Waiting for SLURM job 189919...
# SLURM job 189919 finished.
# Waiting for SLURM job 189920...
# SLURM job 189920 finished.
# Waiting for SLURM job 189921...
# SLURM job 189921 finished.
# Waiting for SLURM job 189922...
# SLURM job 189922 finished.
# Waiting for SLURM job 189923...
# SLURM job 189923 finished.
# Waiting for SLURM job 189924...
# SLURM job 189924 finished.

# %%
cij, bij = get_elastic_tensor(unstrained_atoms, atoms)
cij = cij / units.GPa

c11 = cij[0]
c12 = cij[1]
c44 = cij[2]
c33 = 0
c13 = 0

c11_c12 = c11 - c12
B = (c11 + 2*c12) / 3 
G = (c11_c12 + 3*c44) / 5
E = 9*B*G / (3*B + G)
v = 0.5*(3*B - 2*G)/(3*B + G)

print(f" \'c11\' : {c11:.2f},")
print(f" \'c12\' : {c12:.2f},")
print(f" \'c44\' : {c44:.2f},")
print(f" \'c33\' : {c33:.2f},")
print(f" \'c13\' : {c13:.2f},")
print(f" \'B\' : {B:.2f},")
print(f" \'G\' : {G:.2f},")
print(f" \'E\' : {E:.2f},")
print(f" \'v\' : {v:.2f},")



#print(cij)
# Out:
#  'c11' : 17.33,
#  'c12' : 13.37,
#  'c44' : 10.19,
#  'c33' : 0.00,
#  'c13' : 0.00,
#  'B' : 14.69,
#  'G' : 6.91,
#  'E' : 17.91,
#  'v' : 0.30,

# %% [markdown]
# ## Create and Start PWSCF calculations for the Convex Hull reference

# %%
prototype_dir = Path("/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/AFLOW/aflow_prototype_encyclopedia/data")

AB2_dirs = sorted(
    p for p in prototype_dir.iterdir()
    if p.is_dir() and p.name.startswith("AB2_") or p.name.startswith("A2B_") # load all directory paths as PosixPath objects
)

AB2_strucs = {}

for directory in AB2_dirs:

    atoms_cif = directory / "aflow.cif" #  / "string" just adds string to the path

    if not atoms_cif.exists(): # check if aflow.cif exists in the dir
        continue

    atoms = read(atoms_cif)

    AB2_strucs[directory.name] = atoms

# %%
Li2O_strucs = {}
LiO2_strucs = {} 

for name, atoms in AB2_strucs.items():
    Li2O_strucs[name] = substitute_atoms(atoms, ["O", "Li"] )
    LiO2_strucs[name] = substitute_atoms(atoms, ["Li", "O"] )

Li2O_strucs = {key: value for key, value in Li2O_strucs.items() if len(value) <= 30}
LiO2_strucs = {key: value for key, value in LiO2_strucs.items() if len(value) <= 30}

# remove AB2_hR6_166_c_2c-002 and AB2_tP6_129_c_ac-003

# %%
vc_relax_base_dir = "/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/AFLOW/Li2O"
runbatch_path = "/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/PW-templates/runbatch"
vdW_path = "/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/PW-templates/INP-vdW"
pseudopotentials = {
                    'Li' : 'Li-semi.uspp736-rev2.pbe.UPF',
                    'O' : 'O.uspp736.pbe.UPF'} 
vc_relax_input_data = {
    'calculation'      : 'vc-relax',
    'restart_mode'     : 'from_scratch',
    'pseudo_dir'       : '/ccc160/bmeyer/pot.pwscf/',
    'outdir'           : './',
    'tstress'          : True,
    'etot_conv_thr'    : 1.e-5,
    'tprnfor'          : True,
    'forc_conv_thr'    : 1.e-5,
    'ecutwfc'          : 30.0,
    'ecutrho'          : 120.0,
    'occupations'      : 'smearing',
    'mixing_mode'      : 'plain',
    'smearing'         : 'gauss',
    'degauss'          : 0.01,
    'vdw_corr'         : 'D3-ext',
    'london_rcut'      : 100,
    'diagonalization'  : 'david',
    'electron_maxstep' : 300,
    'conv_thr'         : 1.0e-7,
    'mixing_beta'      : 0.3,
    'koffset'          : (0, 0, 0),
    'ion_dynamics'     : 'bfgs',
    'trust_radius_ini' : 0.1,
    'cell_dynamics'    : 'bfgs',
    'cell_dofree'      : 'all',
    'press_conv_thr'   : 0.5,
    'cell_factor'      : 4.0,
    'nstep'            : 40
}

# %%
Li2O_AB2_pw = run_vc_relax_until_converged(Li2O_strucs, vc_relax_input_data, pseudopotentials,
                                  vc_relax_base_dir, runbatch_path, vdW_path=vdW_path, max_resstarts=10)

AB2_pw_df = pd.DataFrame.from_dict(Li2O_AB2_pw, orient='index')

AB2_pw_df.to_pickle( os.path.join(vc_relax_base_dir, 'Li2O_AB2_pw.pckl.gzip'),
                       compression='gzip',protocol=4)
# Out:
# === restart round 0: 155 structure(s) to (re)run ===
# Waiting for SLURM job 188916...
# SLURM job 188916 finished.
# Waiting for SLURM job 188917...
# SLURM job 188917 finished.
# Waiting for SLURM job 188918...
# SLURM job 188918 finished.
# Waiting for SLURM job 188919...
# SLURM job 188919 finished.
# Waiting for SLURM job 188920...
# SLURM job 188920 finished.
# Waiting for SLURM job 188921...
# SLURM job 188921 finished.
# Waiting for SLURM job 188922...
# SLURM job 188922 finished.
# Waiting for SLURM job 188923...
# SLURM job 188923 finished.
# Waiting for SLURM job 188924...
# SLURM job 188924 finished.
# Waiting for SLURM job 188925...
# SLURM job 188925 finished.
# Waiting for SLURM job 188926...
# SLURM job 188926 finished.
# Waiting for SLURM job 188927...
# SLURM job 188927 finished.
# Waiting for SLURM job 188928...
# SLURM job 188928 finished.
# Waiting for SLURM job 188929...
# SLURM job 188929 finished.
# Waiting for SLURM job 188930...
# SLURM job 188930 finished.
# Waiting for SLURM job 188931...
# SLURM job 188931 finished.
# Waiting for SLURM job 188932...
# SLURM job 188932 finished.
# Waiting for SLURM job 188933...
# SLURM job 188933 finished.
# Waiting for SLURM job 188934...
# SLURM job 188934 finished.
# Waiting for SLURM job 188935...
# SLURM job 188935 finished.
# Waiting for SLURM job 188936...
# SLURM job 188936 finished.
# Waiting for SLURM job 188937...
# SLURM job 188937 finished.
# Waiting for SLURM job 188938...
# SLURM job 188938 finished.
# Waiting for SLURM job 188939...
# SLURM job 188939 finished.
# Waiting for SLURM job 188940...
# SLURM job 188940 finished.
# Waiting for SLURM job 188941...
# SLURM job 188941 finished.
# Waiting for SLURM job 188942...
# SLURM job 188942 finished.
# Waiting for SLURM job 188943...
# SLURM job 188943 finished.
# Waiting for SLURM job 188944...
# SLURM job 188944 finished.
# Waiting for SLURM job 188945...
# SLURM job 188945 finished.
# Waiting for SLURM job 188946...
# SLURM job 188946 finished.
# Waiting for SLURM job 188947...
# SLURM job 188947 finished.
# Waiting for SLURM job 188948...
# SLURM job 188948 finished.
# Waiting for SLURM job 188949...
# SLURM job 188949 finished.
# Waiting for SLURM job 188950...
# SLURM job 188950 finished.
# Waiting for SLURM job 188951...
# SLURM job 188951 finished.
# Waiting for SLURM job 188952...
# SLURM job 188952 finished.
# Waiting for SLURM job 188953...
# SLURM job 188953 finished.
# Waiting for SLURM job 188954...
# SLURM job 188954 finished.
# Waiting for SLURM job 188955...
# SLURM job 188955 finished.
001: 30 ionic/cell steps this round, restarting.
#   AB2_hP9_180_c_i-001: 21 ionic/cell steps this round, restarting.
#   AB2_hR3_160_a_2a-001: 30 ionic/cell steps this round, restarting.
#   AB2_hR3_166_a_c-004: 30 ionic/cell steps this round, restarting.
#   AB2_mC12_12_i_aci-001: 30 ionic/cell steps this round, restarting.
#   AB2_mC18_12_ai_3i-002: 30 ionic/cell steps this round, restarting.
#   AB2_mC6_12_a_i-001: 30 ionic/cell steps this round, restarting.
#   AB2_mC6_12_a_i-003: 24 ionic/cell steps this round, restarting.
#   AB2_mC6_12_a_i-004: 29 ionic/cell steps this round, restarting.
#   AB2_mP12_7_2a_4a-001: 30 ionic/cell steps this round, restarting.
#   AB2_mP6_11_e_2e-001: 30 ionic/cell steps this round, restarting.
#   AB2_oC12_36_a_2a-002: 30 ionic/cell steps this round, restarting.
#   AB2_oC24_41_2a_2b-001: 30 ionic/cell steps this round, restarting.
#   AB2_oC24_64_d_ef-002: 30 ionic/cell steps this round, restarting.
#   AB2_oC6_21_a_k-001: 26 ionic/cell steps this round, restarting.
#   AB2_oC6_21_a_k-002: 30 ionic/cell steps this round, restarting.
#   AB2_oI12_74_e_2e-001: 30 ionic/cell steps this round, restarting.
#   AB2_oI12_74_e_h-001: 30 ionic/cell steps this round, restarting.
#   AB2_oI6_71_a_e-001: 24 ionic/cell steps this round, restarting.
#   AB2_oI6_71_a_e-002: 17 ionic/cell steps this round, restarting.
#   AB2_oP12_29_a_2a-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP12_61_a_c-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP12_61_a_c-002: 30 ionic/cell steps this round, restarting.
#   AB2_oP12_61_a_c-003: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_28_acd_2c3d-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_61_c_2c-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_61_c_2c-002: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_62_2c_4c-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP6_34_a_c-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP6_58_a_g-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP6_58_a_g-002: 29 ionic/cell steps this round, restarting.
#   AB2_oP6_58_a_g-003: 30 ionic/cell steps this round, restarting.
#   AB2_tI12_121_ab_i-001: 30 ionic/cell steps this round, restarting.
#   AB2_tI6_139_a_e-001: 16 ionic/cell steps this round, restarting.
#   AB2_tP12_115_j_egi-001: 30 ionic/cell steps this round, restarting.
#   AB2_tP12_81_adg_2h-001: 30 ionic/cell steps this round, restarting.
#   AB2_tP24_102_d_2cd-001: 30 ionic/cell steps this round, restarting.
#   AB2_tP24_137_g_cdf-001: 30 ionic/cell steps this round, restarting.
#   AB2_tP3_123_a_h-001: 19 ionic/cell steps this round, restarting.
#   AB2_tP6_137_a_d-001: 30 ionic/cell steps this round, restarting.
# === restart round 1: 155 structure(s) to (re)run ===
# Waiting for SLURM job 189071...
# SLURM job 189071 finished.
# Waiting for SLURM job 189072...
# SLURM job 189072 finished.
# Waiting for SLURM job 189073...
# SLURM job 189073 finished.
# Waiting for SLURM job 189074...
# SLURM job 189074 finished.
# Waiting for SLURM job 189075...
# SLURM job 189075 finished.
# Waiting for SLURM job 189076...
# SLURM job 189076 finished.
# Waiting for SLURM job 189077...
# SLURM job 189077 finished.
# Waiting for SLURM job 189078...
# SLURM job 189078 finished.
# Waiting for SLURM job 189079...
# SLURM job 189079 finished.
# Waiting for SLURM job 189080...
# SLURM job 189080 finished.
# Waiting for SLURM job 189081...
# SLURM job 189081 finished.
# Waiting for SLURM job 189082...
# SLURM job 189082 finished.
# Waiting for SLURM job 189083...
# SLURM job 189083 finished.
# Waiting for SLURM job 189084...
# SLURM job 189084 finished.
# Waiting for SLURM job 189085...
# SLURM job 189085 finished.
# Waiting for SLURM job 189086...
# SLURM job 189086 finished.
# Waiting for SLURM job 189087...
# SLURM job 189087 finished.
#   AB2_oI12_74_e_2e-001: 30 ionic/cell steps this round, restarting.
#   AB2_oI12_74_e_h-001: 30 ionic/cell steps this round, restarting.
#   AB2_oI6_71_a_e-001: 8 ionic/cell steps this round, restarting.
#   AB2_oI6_71_a_e-002: 8 ionic/cell steps this round, restarting.
#   AB2_oP12_29_a_2a-001: 15 ionic/cell steps this round, restarting.
#   AB2_oP12_61_a_c-001: 15 ionic/cell steps this round, restarting.
#   AB2_oP12_61_a_c-002: 18 ionic/cell steps this round, restarting.
#   AB2_oP12_61_a_c-003: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_28_acd_2c3d-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_61_c_2c-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_61_c_2c-002: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_62_2c_4c-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP6_34_a_c-001: 28 ionic/cell steps this round, restarting.
#   AB2_oP6_58_a_g-001: 17 ionic/cell steps this round, restarting.
#   AB2_oP6_58_a_g-002: 22 ionic/cell steps this round, restarting.
#   AB2_oP6_58_a_g-003: 28 ionic/cell steps this round, restarting.
#   AB2_tI12_121_ab_i-001: 21 ionic/cell steps this round, restarting.
#   AB2_tI6_139_a_e-001: 7 ionic/cell steps this round, restarting.
#   AB2_tP12_115_j_egi-001: 30 ionic/cell steps this round, restarting.
#   AB2_tP12_81_adg_2h-001: 30 ionic/cell steps this round, restarting.
#   AB2_tP24_102_d_2cd-001: 30 ionic/cell steps this round, restarting.
#   AB2_tP24_137_g_cdf-001: 30 ionic/cell steps this round, restarting.
#   AB2_tP3_123_a_h-001: 12 ionic/cell steps this round, restarting.
#   AB2_tP6_137_a_d-001: 30 ionic/cell steps this round, restarting.
# === restart round 2: 155 structure(s) to (re)run ===
# Waiting for SLURM job 189226...
# SLURM job 189226 finished.
# Waiting for SLURM job 189227...
# SLURM job 189227 finished.
# Waiting for SLURM job 189228...
# SLURM job 189228 finished.
# Waiting for SLURM job 189229...
# SLURM job 189229 finished.
# Waiting for SLURM job 189230...
# SLURM job 189230 finished.
# Waiting for SLURM job 189231...
# SLURM job 189231 finished.
# Waiting for SLURM job 189232...
# SLURM job 189232 finished.
# Waiting for SLURM job 189233...
# SLURM job 189233 finished.
# Waiting for SLURM job 189234...
# SLURM job 189234 finished.
# Waiting for SLURM job 189235...
# SLURM job 189235 finished.
# Waiting for SLURM job 189236...
# SLURM job 189236 finished.
# Waiting for SLURM job 189237...
# SLURM job 189237 finished.
# Waiting for SLURM job 189238...
# SLURM job 189238 finished.
# Waiting for SLURM job 189239...
# SLURM job 189239 finished.
# Waiting for SLURM job 189240...
# SLURM job 189240 finished.
# Waiting for SLURM job 189241...
# SLURM job 189241 finished.
# Waiting for SLURM job 189242...
# SLURM job 189242 finished.
# Job 189242 finished, but 'JOB DONE' was not found in /ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/AFLOW/Li2O/A2B_hP9_150_ef_ad-001/restart_2/OUT.
# Not returning this structure!
# Waiting for SLURM job 189243...
# SLURM job 189243 finished.
# Waiting for SLURM job 189244...
# SLURM job 189244 finished.
# Waiting for SLURM job 189245...
# SLURM job 189245 finished.
# Waiting for SLURM job 189246...
# SLURM job 189246 finished.
# Waiting for SLURM job 189247...
# SLURM job 189247 finished.
# Waiting for SLURM job 189248...
# SLURM job 189248 finished.
# Waiting for SLURM job 189249...
# SLURM job 189249 finished.
# Waiting for SLURM job 189250...
# SLURM job 189250 finished.
# Waiting for SLURM job 189251...
# SLURM job 189353 finished.
# Waiting for SLURM job 189354...
# SLURM job 189354 finished.
# Waiting for SLURM job 189355...
# SLURM job 189355 finished.
# Waiting for SLURM job 189356...
# SLURM job 189356 finished.
# Waiting for SLURM job 189357...
# SLURM job 189357 finished.
# Waiting for SLURM job 189358...
# SLURM job 189358 finished.
# Waiting for SLURM job 189359...
# SLURM job 189359 finished.
# Waiting for SLURM job 189360...
# SLURM job 189360 finished.
# Waiting for SLURM job 189361...
# SLURM job 189361 finished.
# Waiting for SLURM job 189362...
# SLURM job 189362 finished.
# Waiting for SLURM job 189363...
# SLURM job 189363 finished.
# Waiting for SLURM job 189364...
# SLURM job 189364 finished.
# Waiting for SLURM job 189365...
# SLURM job 189365 finished.
# ...
#   A2B_hP18_190_gh_bf-001: 'JOB DONE' not found after restart 6, will retry.
#   A2B_hP6_187_gi_ad-001: 6 ionic/cell steps this round, restarting.
#   A2B_hP6_191_h_e-001: 5 ionic/cell steps this round, restarting.
#   A2B_hP9_147_g_ad-001: converged after 7 restart(s).
#   A2B_hP9_147_g_ad-002: 27 ionic/cell steps this round, restarting.
#   A2B_hP9_150_ef_ad-001: 'JOB DONE' not found after restart 6, will retry.
#   A2B_hP9_180_i_d-001: 'JOB DONE' not found after restart 6, will retry.
#   A2B_hP9_189_fg_ad-001: 4 ionic/cell steps this round, restarting.
#   A2B_mC12_12_2i_i-004: 14 ionic/cell steps this round, restarting.
#   A2B_mC12_12_2i_i-007: 26 ionic/cell steps this round, restarting.
#   A2B_mC12_15_f_a-001: 13 ionic/cell steps this round, restarting.
#   A2B_mC12_5_2c_c-001: converged after 7 restart(s).
#   A2B_mP12_13_2g_ef-001: converged after 7 restart(s).
#   A2B_mP12_14_2e_e-011: 8 ionic/cell steps this round, restarting.
#   A2B_mP12_14_2e_e-012: 6 ionic/cell steps this round, restarting.
#   A2B_mP12_3_ab3e_2e-001: converged after 7 restart(s).
#   A2B_mP18_7_6a_3a-001: 15 ionic/cell steps this round, restarting.
#   A2B_oC12_36_2a_a-001: 8 ionic/cell steps this round, restarting.
#   A2B_oC12_38_de_ab-001: 4 ionic/cell steps this round, restarting.
#   A2B_oC12_63_2c_c-001: 7 ionic/cell steps this round, restarting.
#   A2B_oC12_65_acg_h-001: converged after 7 restart(s).
#   A2B_oC24_20_abc_c-001: 30 ionic/cell steps this round, restarting.
#   A2B_oC24_63_acg_f-001: 30 ionic/cell steps this round, restarting.
#   A2B_oC24_64_2f_f-001: 22 ionic/cell steps this round, restarting.
#   A2B_oC24_64_ef_f-001: 6 ionic/cell steps this round, restarting.
#   A2B_oF24_70_e_a-001: converged after 7 restart(s).
#   A2B_oI12_71_eh_f-001: 8 ionic/cell steps this round, restarting.
#   A2B_oI12_74_h_e-001: 30 ionic/cell steps this round, restarting.
#   A2B_oP12_17_abe_e-001: 14 ionic/cell steps this round, restarting.
#   A2B_oP12_18_2c_c-001: 9 ionic/cell steps this round, restarting.
#   A2B_oP12_26_abc_ab-001: 7 ionic/cell steps this round, restarting.
#   A2B_oP12_26_abc_ab-002: 4 ionic/cell steps this round, restarting.
#   A2B_oP12_31_4a_2a-001: 9 ionic/cell steps this round, restarting.
#   A2B_oP12_62_2c_c-001: 6 ionic/cell steps this round, restarting.
#   A2B_oP12_62_2c_c-002: 6 ionic/cell steps this round, restarting.
#   A2B_oP12_62_2c_c-003: 5 ionic/cell steps this round, restarting.
#   A2B_oP12_62_2c_c-004: 6 ionic/cell steps this round, restarting.
#   A2B_oP12_62_2c_c-010: converged after 7 restart(s).
#   A2B_oP24_26_2a2b2c_2a2b-001: 30 ionic/cell steps this round, restarting.
#   A2B_oP24_52_2e_cd-001: 6 ionic/cell steps this round, restarting.
#   A2B_oP24_55_2g2h_gh-001: converged after 7 restart(s).
#   A2B_tI12_141_e_a-002: 30 ionic/cell steps this round, restarting.
#   A2B_tI24_107_2abc_2ab-001: 8 ionic/cell steps this round, restarting.
#   A2B_tI24_141_2e_e-001: 30 ionic/cell steps this round, restarting.
#   A2B_tP12_92_b_a-001: 18 ionic/cell steps this round, restarting.
#   A2B_tP24_135_gh_h-001: 4 ionic/cell steps this round, restarting.
#   A2B_tP24_92_2b_b-001: 6 ionic/cell steps this round, restarting.
#   A2B_tP6_136_f_a-001: 6 ionic/cell steps this round, restarting.
#   AB2_hP12_194_f_ah-001: 3 ionic/cell steps this round, restarting.
#   AB2_hP24_194_ef_fgh-001: 30 ionic/cell steps this round, restarting.
#   AB2_hP6_186_b_ab-001: 3 ionic/cell steps this round, restarting.
#   AB2_hP6_194_b_f-001: 14 ionic/cell steps this round, restarting.
#   AB2_hP6_194_b_f-002: 12 ionic/cell steps this round, restarting.
#   AB2_hP6_194_c_f-001: 7 ionic/cell steps this round, restarting.
#   AB2_hP9_162_ad_k-001: 3 ionic/cell steps this round, restarting.
#   AB2_hP9_164_ad_c2d-001: 17 ionic/cell steps this round, restarting.
#   AB2_hP9_180_c_i-001: 6 ionic/cell steps this round, restarting.
#   AB2_hR3_160_a_2a-001: 4 ionic/cell steps this round, restarting.
#   AB2_hR3_166_a_c-004: converged after 7 restart(s).
#   AB2_mC12_12_i_aci-001: 30 ionic/cell steps this round, restarting.
#   AB2_mP6_11_e_2e-001: 3 ionic/cell steps this round, restarting.
#   AB2_oC12_36_a_2a-002: 5 ionic/cell steps this round, restarting.
#   AB2_oC6_21_a_k-001: 5 ionic/cell steps this round, restarting.
#   AB2_oC6_21_a_k-002: 9 ionic/cell steps this round, restarting.
#   AB2_oI12_74_e_2e-001: 30 ionic/cell steps this round, restarting.
#   AB2_oI12_74_e_h-001: 30 ionic/cell steps this round, restarting.
#   AB2_oP24_28_acd_2c3d-001: 8 ionic/cell steps this round, restarting.
#   AB2_oP6_34_a_c-001: 6 ionic/cell steps this round, restarting.
#   AB2_oP6_58_a_g-001: 3 ionic/cell steps this round, restarting.
#   AB2_oP6_58_a_g-002: 16 ionic/cell steps this round, restarting.
#   AB2_tI12_121_ab_i-001: 14 ionic/cell steps this round, restarting.
#   AB2_tP12_115_j_egi-001: 26 ionic/cell steps this round, restarting.
#   AB2_tP12_81_adg_2h-001: 12 ionic/cell steps this round, restarting.
#   AB2_tP24_137_g_cdf-001: 4 ionic/cell steps this round, restarting.
# === restart round 7: 68 structure(s) to (re)run ===
# Waiting for SLURM job 189828...
# SLURM job 189828 finished.
# Waiting for SLURM job 189829...
# SLURM job 189829 finished.
# Waiting for SLURM job 189830...
# SLURM job 189830 finished.
# Job 189830 finished, but 'JOB DONE' was not found in /ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/AFLOW/Li2O/A2B_hP18_180_fj_ac-001/restart_7/OUT.
# Not returning this structure!
# Waiting for SLURM job 189831...
# SLURM job 189831 finished.
# Job 189831 finished, but 'JOB DONE' was not found in /ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/AFLOW/Li2O/A2B_hP18_190_gh_bf-001/restart_7/OUT.
# Not returning this structure!
# Waiting for SLURM job 189832...
# SLURM job 189832 finished.
# Waiting for SLURM job 189833...
# SLURM job 189833 finished.
# Waiting for SLURM job 189834...
# SLURM job 189834 finished.
# Waiting for SLURM job 189835...
# SLURM job 189835 finished.
# Job 189835 finished, but 'JOB DONE' was not found in /ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf
# Waiting for SLURM job 189881...
# SLURM job 189881 finished.
# Waiting for SLURM job 189882...
# SLURM job 189882 finished.
# Waiting for SLURM job 189883...
# SLURM job 189883 finished.
# Waiting for SLURM job 189884...
# SLURM job 189884 finished.
# Waiting for SLURM job 189885...
# SLURM job 189885 finished.
# Waiting for SLURM job 189886...
# SLURM job 189886 finished.
# Waiting for SLURM job 189887...
# SLURM job 189887 finished.
# Waiting for SLURM job 189888...
# SLURM job 189888 finished.
# Waiting for SLURM job 189889...
# SLURM job 189889 finished.
# Waiting for SLURM job 189890...
# SLURM job 189890 finished.
# Waiting for SLURM job 189891...
# SLURM job 189891 finished.
# Waiting for SLURM job 189892...
# SLURM job 189892 finished.
# Waiting for SLURM job 189893...
# SLURM job 189893 finished.
# Waiting for SLURM job 189894...
# SLURM job 189894 finished.
# Waiting for SLURM job 189895...
# SLURM job 189895 finished.
#   A2B_aP6_2_aei_i-001: 15 ionic/cell steps this round, restarting.
#   A2B_cP24_215_ei_ace-001: 6 ionic/cell steps this round, restarting.
#   A2B_hP18_180_fj_ac-001: 'JOB DONE' not found after restart 7, will retry.
#   A2B_hP18_190_gh_bf-001: 'JOB DONE' not found after restart 7, will retry.
#   A2B_hP6_187_gi_ad-001: 6 ionic/cell steps this round, restarting.
#   A2B_hP6_191_h_e-001: 3 ionic/cell steps this round, restarting.
#   A2B_hP9_147_g_ad-002: 13 ionic/cell steps this round, restarting.
#   A2B_hP9_150_ef_ad-001: 'JOB DONE' not found after restart 7, will retry.
#   A2B_hP9_180_i_d-001: 'JOB DONE' not found after restart 7, will retry.
#   A2B_hP9_189_fg_ad-001: 4 ionic/cell steps this round, restarting.
#   A2B_mC12_12_2i_i-004: 5 ionic/cell steps this round, restarting.
#   A2B_mC12_12_2i_i-007: 14 ionic/cell steps this round, restarting.
#   A2B_mC12_15_f_a-001: converged after 8 restart(s).
#   A2B_mP12_14_2e_e-011: 8 ionic/cell steps this round, restarting.
#   A2B_mP12_14_2e_e-012: 5 ionic/cell steps this round, restarting.
#   A2B_mP18_7_6a_3a-001: 6 ionic/cell steps this round, restarting.
#   A2B_oC12_36_2a_a-001: 4 ionic/cell steps this round, restarting.
#   A2B_oC12_38_de_ab-001: 4 ionic/cell steps this round, restarting.
#   A2B_oC12_63_2c_c-001: 7 ionic/cell steps this round, restarting.
#   A2B_oC24_20_abc_c-001: 30 ionic/cell steps this round, restarting.
#   A2B_oC24_63_acg_f-001: 29 ionic/cell steps this round, restarting.
#   A2B_oC24_64_2f_f-001: 16 ionic/cell steps this round, restarting.
#   A2B_oC24_64_ef_f-001: 4 ionic/cell steps this round, restarting.
#   A2B_oI12_71_eh_f-001: 8 ionic/cell steps this round, restarting.
#   A2B_oI12_74_h_e-001: 30 ionic/cell steps this round, restarting.
#   A2B_oP12_17_abe_e-001: 4 ionic/cell steps this round, restarting.
#   A2B_oP12_18_2c_c-001: 4 ionic/cell steps this round, restarting.
#   A2B_oP12_26_abc_ab-001: 7 ionic/cell steps this round, restarting.
#   A2B_oP12_26_abc_ab-002: 4 ionic/cell steps this round, restarting.
#   A2B_oP12_31_4a_2a-001: 4 ionic/cell steps this round, restarting.
#   A2B_oP12_62_2c_c-001: 4 ionic/cell steps this round, restarting.
#   A2B_oP12_62_2c_c-002: 4 ionic/cell steps this round, restarting.
#   A2B_oP12_62_2c_c
-001', 'A2B_mC12_12_2i_i-004', 'A2B_mC12_12_2i_i-007', 'A2B_mP12_14_2e_e-011', 'A2B_mP12_14_2e_e-012', 'A2B_mP18_7_6a_3a-001', 'A2B_oC12_36_2a_a-001', 'A2B_oC12_38_de_ab-001', 'A2B_oC12_63_2c_c-001', 'A2B_oC24_20_abc_c-001', 'A2B_oC24_63_acg_f-001', 'A2B_oC24_64_2f_f-001', 'A2B_oC24_64_ef_f-001', 'A2B_oI12_71_eh_f-001', 'A2B_oI12_74_h_e-001', 'A2B_oP12_17_abe_e-001', 'A2B_oP12_18_2c_c-001', 'A2B_oP12_26_abc_ab-001', 'A2B_oP12_26_abc_ab-002', 'A2B_oP12_31_4a_2a-001', 'A2B_oP12_62_2c_c-001', 'A2B_oP12_62_2c_c-002', 'A2B_oP12_62_2c_c-003', 'A2B_oP12_62_2c_c-004', 'A2B_oP24_26_2a2b2c_2a2b-001', 'A2B_oP24_52_2e_cd-001', 'A2B_tI12_141_e_a-002', 'A2B_tI24_107_2abc_2ab-001', 'A2B_tI24_141_2e_e-001', 'A2B_tP12_92_b_a-001', 'A2B_tP24_135_gh_h-001', 'A2B_tP24_92_2b_b-001', 'A2B_tP6_136_f_a-001', 'AB2_hP12_194_f_ah-001', 'AB2_hP24_194_ef_fgh-001', 'AB2_hP6_186_b_ab-001', 'AB2_hP6_194_b_f-001', 'AB2_hP6_194_b_f-002', 'AB2_hP6_194_c_f-001', 'AB2_hP9_162_ad_k-001', 'AB2_hP9_164_ad_c2d-001', 'AB2_hP9_180_c_i-001', 'AB2_hR3_160_a_2a-001', 'AB2_mC12_12_i_aci-001', 'AB2_oC12_36_a_2a-002', 'AB2_oC6_21_a_k-001', 'AB2_oC6_21_a_k-002', 'AB2_oI12_74_e_2e-001', 'AB2_oI12_74_e_h-001', 'AB2_oP6_34_a_c-001', 'AB2_oP6_58_a_g-001', 'AB2_oP6_58_a_g-002', 'AB2_tI12_121_ab_i-001', 'AB2_tP12_115_j_egi-001', 'AB2_tP12_81_adg_2h-001', 'AB2_tP24_137_g_cdf-001']

# %% [markdown]
# ## materials project stuff

# %%
with MPRester('1rrCd5o3r69gbghUDV5fFzuncBdu1uVF') as mpr:
    docs_LiO = mpr.materials.summary.search(
        chemsys=["Li-O"],
        fields=["material_id","structure","composition",'formula_pretty','energy_per_atom']
    )
    li_docs = mpr.materials.summary.search(
        chemsys=["Li"],
        fields=[
            "material_id",
            "structure",
            "composition",
            "formula_pretty",
            "energy_per_atom",
        ]
    )

    # Elemental O
    o_docs = mpr.materials.summary.search(
        chemsys=["O"],
        fields=[
            "material_id",
            "structure",
            "composition",
            "formula_pretty",
            "energy_per_atom",
        ]
    )
docs = docs_LiO.copy()
docs.extend(li_docs)
docs.extend(o_docs)

# %% [markdown]
# # Create test structure dict

# %% [markdown]
# ## Load and optimize test structures

# %%
set_calculator(calc)
Li2O_bulk = Atoms(symbols='Li8O4',
            scaled_positions=[    
                    [0.25000000,   0.25000000,   0.75000000],
                    [0.25000000,   0.75000000,   0.75000000],
                    [0.25000000,   0.75000000,   0.25000000],
                    [0.25000000,   0.25000000,   0.25000000],
                    [0.75000000,   0.25000000,   0.25000000],
                    [0.75000000,   0.75000000,   0.25000000],
                    [0.75000000,   0.75000000,   0.75000000],
                    [0.75000000,   0.25000000,   0.75000000],
                    [0.00000000,   0.00000000,   0.00000000],
                    [0.00000000,   0.50000000,   0.50000000],
                    [0.50000000,   0.00000000,   0.50000000],
                    [0.50000000,   0.50000000,   0.00000000]
                ],
            cell=[[4.608, 0.00, 0.00],
                    [0.00, 4.608, 0.00],
                    [0.00, 0.00, 4.608]],
            pbc=True,
            info={'n_units':4},
            calculator = calc)

Li_bcc_bulk = Atoms(symbols='Li2',
            scaled_positions=[    
                    [0.00000000,   0.00000000,   0.00000000],
                    [0.50000000,   0.50000000,   0.50000000]
                ],
            cell=[[3.425, 0.00, 0.00],
                    [0.00, 3.425, 0.00],
                    [0.00, 0.00, 3.425]],
            pbc=True,
            info={'n_units':2},
            calculator = calc
                   )

Li_fcc_bulk = Atoms(symbols='Li4',
            scaled_positions=[    
                    [0.00000000,   0.00000000,   0.00000000],
                    [0.50000000,   0.50000000,   0.00000000],
                    [0.00000000,   0.50000000,   0.50000000],
                    [0.50000000,   0.00000000,   0.50000000]
                ],
            cell=[[4.305, 0.00, 0.00],
                    [0.00, 4.305, 0.00],
                    [0.00, 0.00, 4.305]],
            pbc=True,
            info={'n_units':3},
            calculator = calc
                   )




a_Li2O2=3.1431 # in Angstrom
Li2O2_bulk = Atoms(symbols='Li4O4',
            scaled_positions=
                   [ 
                     [0.00000000, 0.00000000, 0.50000000],
                     [0.00000000, 0.00000000, 0.00000000],
                     [0.66666738, 0.33333476, 0.75      ],
                     [0.33333262, 0.66666524, 0.25      ],
                     [0.66666744, 0.33333487, 0.14861931],
                     [0.33333256, 0.66666513, 0.64861931],
                     [0.33333256, 0.66666513, 0.85138069],
                     [0.66666744, 0.33333487, 0.35138069]
                   ],
             cell = [[a_Li2O2, 0, 0],
                    [-a_Li2O2/2, np.sqrt(3)*a_Li2O2/2, 0],
                    [0, 0, 2.433*a_Li2O2]],
            pbc=True,
            info={'n_units':2},
            calculator = calc)





O2_molecule = Atoms(symbols='O2',
                    positions=[[10,10,10],[10,10,11.22]],
                    cell=[50,50,50],
                    pbc=True,
                    info={'n_units':2}, # needed because the energy per O atom makes calculating formation energies easier
                    calculator = calc)

BFGS(O2_molecule,logfile=None).run(fmax=0.0001) # optimize atomic positions
### MLP O2-molecule energy 
O2_energy = O2_molecule.get_potential_energy()
###


# all bulk structures in a list with a name. 
#opt_cell() optimizes the cell and positions

bulk_strucs = [['Li2O', opt_cell(Li2O_bulk, logfile=None)],
               ['Li_bcc', opt_cell(Li_bcc_bulk,logfile=None)],
               ['Li_fcc', opt_cell(Li_fcc_bulk,logfile=None)],
               ['Li2O2', opt_cell(Li2O2_bulk,logfile=None)]]

# %% [markdown]
# ## Create dictionary with all important values

# %%
bulk_strucs_dict={}
for name, struc in bulk_strucs:
    bulk_strucs_dict[name]={
                            'ase_atoms' : struc, # ASE Atoms object of the optimized structures
                            'lattice' : lattice_ident(struc), # get lattice parameters and type
                            'elast_const' : calc_elast_const(struc), # get all the elastic constants
                            }

# %% [markdown]
# ### Surfaces

# %%
set_calculator(calc)

######################
### for example hexagonal {h,k,i,l} miller-bravais indices 
### have to transformed to (h,k,l) miller indices
### for pymat SlabGenerator to read them
### via i= -(h+k) 
### 
### ex: 
### {0001} -->	(0,0,1)
### {1(-1)00} -->	(1,-1,0)
### {11(-2)0} -->	(1,1,0)
######################

cub_surfs = [ [1,0,0], [1,1,0], [1,1,1] ]
other_surfs = [ [0,0,1], [1,-1,0], [1,1,0] ]


for name,struc in bulk_strucs_dict.items(): 
    bulk_strucs_dict[name]['surfaces'] = {}
    print(name)
    if 'lattice' not in struc:
        continue
        
    if bulk_strucs_dict[name]['lattice']['type'] == 'CUB':
        for surf in cub_surfs:
            key = f"{surf[0]}{surf[1]}{surf[2]}"
            bulk_strucs_dict[name]['surfaces'][key] =  find_stable_surface( struc['ase_atoms'], surf[0],surf[1],surf[2], nrep=6)   

####  Works, but Li2O2 is bad for my mlp
    elif bulk_strucs_dict[name]['lattice']['type'] != 'CUB':
        for surf in other_surfs:
            key = f"{surf[0]}{surf[1]}{surf[2]}"
            bulk_strucs_dict[name]['surfaces'][key] =  find_stable_surface( struc['ase_atoms'], surf[0],surf[1],surf[2], nrep=3, opt=True)
    else:
        continue
# Out:
# Li2O
# Li_bcc
# Li_fcc
# Li2O2
# Low energy (0, 0, 1) surface found, starting geo-opt.
#  (0, 0, 1) done !
# Low energy (1, -1, 0) surface found, starting geo-opt.
#  (1, -1, 0) done !
# Low energy (1, 1, 0) surface found, starting geo-opt.
#  (1, 1, 0) done !

# %% [markdown]
# ### get bulk atomic reference energies and add formation energy to dict

# %%
# Add gas phase molecules to your dictionary
bulk_strucs_dict['O2']={ 'ase_atoms' : O2_molecule}

# %%
# for formation energy calc
# its basically just your mlp energy divided by the number of units
# can also put in values by hand
# dict has to contain the elemental reference energies per atom
# in this case for example:
# Li => energy the mlp predicts for solid lithium per Li-atom
# O => energy the mlp predicts for an isolated O2 molecule per O-atom

set_calculator(calc)

ref_bulk_mlp = get_bulk_ref(bulk_strucs_dict)

# Add formation energies to your dictionary in kJ/mol (if your mlp works in eV)
for name in bulk_strucs_dict:
    bulk_strucs_dict[name]['Ef_kJ'] = get_formation_energy(bulk_strucs_dict[name]['ase_atoms'], ref_bulk_mlp)*96.485 # in kJ/mol
# Out:
# Skipping Li8O4: not a single-element structure, can't use it as an elemental reference.
# Skipping Li4O4: not a single-element structure, can't use it as an elemental reference.
# Li reference: Li (-7.4274 eV total, -1.8569 eV/atom)
# O reference: O2 (-8.5030 eV total, -4.2515 eV/atom)

# %% [markdown]
# # Phonons

# %%
#pot_functions.set_calculator(calc)
phonon, fig = get_phonon_spectrum(bulk_strucs_dict['Li2O']['ase_atoms'], calc=calc)
# Out:
# No supercell_matrix given, using automatic supercell (diag):
# [4 4 4]
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['transformation_matrix']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['international']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['rotations']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['translations']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['number']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['wyckoffs']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['equivalent_atoms']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# Generated 2 displaced supercell(s), computing forces...
#   supercell 1/2 done.
#   supercell 2/2 done.
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_lattice']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_positions']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_types']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /ccc160/akirsan/miniforge3/envs/ace/lib/python3.10/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_rotation_matrix']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# Phonon spectrum calculation done.

# %% [markdown]
# # Dataset Tests

# %% [markdown]
# ## create analysis_data

# %%
mlp_f = []
mlp_e = []
pw_e = []
pw_f = []
diff_f = []
diff_e = []
gamma_list = []
gamma_mean_list = []

ase_list = []
dens_list = []
name_list = []

for i, (atoms, name, pw_energy, pw_forces) in enumerate(
    zip(strucs_all['ase_atoms'],
        strucs_all['name'],
        strucs_all['energy_corrected'],
        strucs_all['forces'])):

    struc = atoms.copy()
    struc.calc = calc

    nat = len(struc)

    ############################
    ###### general stuff #######
    ############################

    mass = struc.get_masses().sum()
    vol = struc.get_volume()

    dens = (mass * _amu) / (vol * 1e-27)
    dens_list.append(dens)

    struc_save = struc.copy()
    struc_save.calc = None

    ase_list.append(struc_save)
    name_list.append(name)

    ############################
    ##### Energies & Gamma #####
    ############################

    mlp_energy = struc.get_potential_energy()
    mlp_energy_pa = mlp_energy / nat

    pw_energy_pa = pw_energy / nat

    mlp_e.append(mlp_energy_pa)
    pw_e.append(pw_energy_pa)

    diff_e.append(1000 * (mlp_energy_pa - pw_energy_pa) )

    gamma = np.asarray(calc.results["gamma"])

    gamma_list.append(gamma.copy())
    gamma_mean_list.append(gamma.mean())

    ############################
    ########## Forces ########## 
    ############################

    pw_forces = np.asarray(pw_forces)
    mlp_forces = struc.get_forces()

    pw_norm = np.linalg.norm(pw_forces, axis=1)
    mlp_norm = np.linalg.norm(mlp_forces, axis=1)

    pw_f.append(pw_norm)
    mlp_f.append(mlp_norm)

    diff_f.append(1000 * (mlp_norm - pw_norm) )



####################################################################
########## Save calcs as dictionary and save as pckl file ########## 
####################################################################

analysis_data = {
    'name': name_list,
    'ase_atoms': ase_list,
    'density': dens_list,
    'pw_e_pA': pw_e,
    'mlp_e_pA': mlp_e,
    'diff_e_pA': diff_e,
    'pw_f': pw_f,
    'mlp_f': mlp_f,
    'diff_f': diff_f,
    'gamma_i': gamma_list,
    'gamma_mean': gamma_mean_list
}

analysis_df = pd.DataFrame(analysis_data)

analysis_df.to_pickle( os.path.join(analysis_path, 'analysis.pckl.gzip'),
                       compression='gzip',protocol=4)

# %% [markdown]
# ## convex hull

# %% [markdown]
# ### PWSCF Convex Hull Data

# %%
pw_Li2O_df=pd.read_pickle("/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/AFLOW/Li2O/Li2O_AB2_pw.pckl.gzip", compression="gzip")
#pw_LiO2_df=pd.read_pickle("/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/AFLOW/LiO2/LiO2_AB2_pw.pckl.gzip", compression="gzip")


## To-Do
#pw_Li2O2_df=pd.read_pickle("/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O2-pwscf/AFLOW/Li2O2/Li2O2_A2B2_pw.pckl.gzip", compression="gzip")

# %%
pw_LiO = pd.concat([pw_Li2O_df, pw_LiO2_df])
Li2O_pw_bulk = read('/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/scf-opt/OUT', format = 'espresso-out')
Li2O2_pw_bulk = read('/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O2-pwscf/scf-opt/OUT', format = 'espresso-out')

stable_strucs = []
stable_strucs.append({
            'name' : 'Li2O',
            'ase_atoms': Li2O_pw_bulk,
            'potential_energy': Li2O_pw_bulk.get_potential_energy(),
            'forces': Li2O_pw_bulk.get_forces()
        })
stable_strucs.append({
            'name' : 'Li2O2',
            'ase_atoms': Li2O2_pw_bulk,
            'potential_energy': Li2O2_pw_bulk.get_potential_energy(),
            'forces': Li2O2_pw_bulk.get_forces()
        })
new_df = pd.DataFrame(stable_strucs)

# %%
pw_LiO_df = pd.concat([pw_LiO_df, new_df])

# %%
entries = []

for i in range(len(pw_LiO_df['ase_atoms'])):
        name = pw_LiO_df.['name'][i]
        atoms = AseAtomsAdaptor.get_structure(pw_LiO_df['ase_atoms'][i])
        energy = pw_LiO_df['potential_energy'][i]

        entries.append(
        PDEntry(
            composition=atoms.composition,
            energy=energy
        )
    )

for element, (formula, ref_energy) in element_refs.items():
    entries.append(PDEntry(composition=formula, energy=ref_energy))


p_diag = PhaseDiagram(entries)
# Out:
# /tmp/ipykernel_43137/4088208976.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   atoms = AseAtomsAdaptor.get_structure(pw_Li2O_df['ase_atoms'][i])
# /tmp/ipykernel_43137/4088208976.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   energy = pw_Li2O_df['potential_energy'][i]

# %%
plotter = PDPlotter(
    p_diag,
    backend="matplotlib",
    show_unstable=True,
)
ax = plotter.get_plot()

# %% [markdown]
# ## plots

# %% [markdown]
# ### Visualize a structure with colorcoding

# %%
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

sc = ax.scatter(
    coords[:, 0],  # x
    coords[:, 1],  # y
    coords[:, 2],  # z
    #c=test_diff,       # color according to force magnitude
    c=gamma_list,
    cmap="viridis",
    s=50
)

# Draw bonds
cutoff = 1.25

for i in range(len(coords)):
    for j in range(i + 1, len(coords)):
        distance = np.linalg.norm(coords[i] - coords[j])

        if distance < cutoff:
            ax.plot(
                [coords[i, 0], coords[j, 0]],
                [coords[i, 1], coords[j, 1]],
                [coords[i, 2], coords[j, 2]],
                linewidth=1,
                color="black"
            )


ax.set_xlabel("x (Å)")
ax.set_ylabel("y (Å)")
ax.set_zlabel("z (Å)")

# Colorbar showing force magnitude
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label("Force magnitude")

plt.show()

# %% [markdown]
# # Binding Curves

# %% [markdown]
# ## O2-molecule

# %%
monomer_dmp=[]

for i in range(0, 30):
    name = f"O2_noPBC_monomer_{i}_OUT"

    if name in analysis_data['name']:
        idx = analysis_data['name'].index(name)
        
        atoms = analysis_data['ase_atoms'][idx]
        coords = atoms.get_positions()
        #molecule = atoms[[0, 1]]

        distance = np.linalg.norm(coords[1]-coords[0])

        monomer_dmp.append([distance,
                         analysis_data['pw_e_pA'][idx],
                         analysis_data['mlp_e_pA'][idx],
                         analysis_data['mlp_e_pA'][idx]-analysis_data['pw_e_pA'][idx],
                         ]) #d ,pw, mlp, diff
        
monomer_dmp = np.array(monomer_dmp)
monomer_dmp = monomer_dmp[monomer_dmp[:, 0].argsort()]

plt.plot(monomer_dmp[:,0], monomer_dmp[:,1], 'o-', label="PW")
plt.plot(monomer_dmp[:,0], monomer_dmp[:,2], 'o-', label="MLP")
#plt.plot(monomer_dmp[:,0], monomer_dmp[:,3], 'o-', label="MLP-PW")

plt.xlabel("O–O distance (Å)")
plt.ylabel("Energy (eV/atom)")
plt.legend()
plt.show()

# %% [markdown]
# ### BDC str-gen

# %%
e_list = []
d_list=[]
f_list=[]
atoms_list=[]

atoms_init = Atoms('O2', positions=[[25, 25, 25], [25, 25, 26.23]], cell=[30,30,30], pbc=True)
#atoms_init.center(vacuum=10.0)

#atoms_init = read('/ccc160/akirsan/PhD/MLP/Li2O/str-gen/O2/vdw-PBC/str_0/OUT', format = 'espresso-out')

#atoms.set_calculator(test_calc)

step = 0.2
nsteps = 20

for i in range(nsteps):
    d = 1 + i * step
    atoms_init.positions[1, 2] = atoms_init.positions[0, 2] + d
    atoms=atoms_init.copy()
    #atoms_init.center(vacuum=20.0)
    atoms=atoms_init.copy()
    atoms.set_calculator(calc)
    atoms_list.append(atoms.copy())
    e = atoms.get_potential_energy()
    f = atoms.get_forces()
    e_list.append(e)
    d_list.append(d)
    f_list.append(np.linalg.norm(f))
    #print('distance, energy', d, e)
    #print('force', f)
'''
for i in range(10):
    d = 1.1 + i* 0.03
    atoms_init.positions[1, 2] = atoms_init.positions[0, 2] + d
    atoms=atoms_init.copy()
    #atoms_init.center(vacuum=20.0)
    atoms=atoms_init.copy()
    atoms.set_calculator(calc)
    atoms_list.append(atoms.copy())
    e = atoms.get_potential_energy()
    f = atoms.get_forces()
    e_list.append(e)
    d_list.append(d)
    f_list.append(np.linalg.norm(f))
    #print('distance, energy', d, e)
    #print('force', f)
'''


plt.plot(d_list, e_list)
#plt.plot(d_list, f_list)
#view(atoms_list, viewer='ngl')
#plt.show()

# %% [markdown]
# ## O2-dimer

# %%
dimer_dmp=[]


# 0 - 19 : | |
# 20 - 39 : x |
# 40 - 59 : -- -- 
# 60 - 79 : x -- 

for i in range(20, 40):
    name = f"O2_noPBC_dimer_{i}_OUT"

    if name in analysis_data['name']:
        idx = analysis_data['name'].index(name)
        
        atoms = analysis_data['ase_atoms'][idx]

        dimer1 = atoms[[0, 1]]
        dimer2 = atoms[[2, 3]]

        com1 = dimer1.get_center_of_mass()
        com2 = dimer2.get_center_of_mass()

        distance = np.linalg.norm(com1 - com2)

        dimer_dmp.append([distance,
                         analysis_data['pw_e_pA'][idx],
                         analysis_data['mlp_e_pA'][idx],
                         analysis_data['mlp_e_pA'][idx]-analysis_data['pw_e_pA'][idx],
                         ]) #d ,pw, mlp, diff
        
        #pw_dmp.append(analysis_data['pw_e_pA'][idx])
        #mlp_dmp.append(analysis_data['mlp_e_pA'][idx])

dimer_dmp = np.array(dimer_dmp)
#plt.plot(dimer_dmp[:,0], dimer_dmp[:,1], 'o-', label="PW")
#plt.plot(dimer_dmp[:,0], dimer_dmp[:,2], 'o-', label="MLP")
plt.plot(dimer_dmp[:,0], dimer_dmp[:,3], 'o-', label="MLP-PW")

plt.xlabel("O$_2$–O$_2$ distance (Å)")
plt.ylabel("Energy (eV/atom)")
plt.legend()
plt.show()

# %% [markdown]
# ### Dimer str-gen

# %%
e_list = []
d_list=[]
f_list=[]
atoms_list=[]

#atoms_init = Atoms('O4', positions=[[5, 5, 5], [5, 5, 6.225],[6, 5, 5], [6, 5, 6.225] ], cell=[30,30,30], pbc=True)

step = 0.2
nsteps = 20

####################
####### o o ########
####### | | ########
####### o o ########
####################
for i in range(nsteps):
    d = 1.2 + i * step
    #d = step
    atoms_init = Atoms('O4', positions=[[5, 5, 4.3875], [5, 5, 5.6125],[5, 5, 4.3875], [5, 5, 5.6125] ], cell=[30,30,30], pbc=True)
    atoms_init.positions[2,0] = atoms_init.positions[2, 0]+d
    atoms_init.positions[3,0] = atoms_init.positions[3, 0]+d
    atoms=atoms_init.copy()
    atoms.set_calculator(calc)
    atoms_list.append(atoms.copy())
    e = atoms.get_potential_energy()
    f = atoms.get_forces()
    e_list.append(e)
    d_list.append(d)
    #f_list.append(np.linalg.norm(f))
    #print('distance, energy', d, e)
    #print('force', f)
#plt.plot(d_list, e_list)
#plt.plot(d_list, f_list)
#view(atoms_list, viewer='ngl')

###################
######## o ########
###### x | ########
######## o ########
###################
for i in range(nsteps):
    d = 1.2 + i * step
    #d = step
    atoms_init = Atoms('O4', positions=[[5, 5, 4.3875], [5, 5, 5.6125],[5, 4.3875, 5], [5, 5.6125, 5] ], cell=[30,30,30], pbc=True)
    atoms_init.positions[2,0] = atoms_init.positions[2, 0]+d
    atoms_init.positions[3,0] = atoms_init.positions[3, 0]+d
    atoms=atoms_init.copy()
    atoms_list.append(atoms.copy())

    
##################
##################
#### o-o o-o #####
##################
##################
for i in range(nsteps):
    d = 2.4 + i * step
    #d = step
    atoms_init = Atoms('O4', positions=[[4.3875, 5, 5], [5.6125, 5, 5],[4.3875, 5, 5], [5.6125, 5, 5] ], cell=[30,30,30], pbc=True)
    atoms_init.positions[2,0] = atoms_init.positions[2, 0]+d
    atoms_init.positions[3,0] = atoms_init.positions[3, 0]+d
    atoms=atoms_init.copy()
    atoms_list.append(atoms.copy())

###################
######## o ########
#### o-o | ########
######## o ########
###################
for i in range(nsteps):
    d = 1.4 + i * step
    #d = step
    atoms_init = Atoms('O4', positions=[[5, 5, 4.3875], [5, 5, 5.6125],[4.3875, 5, 5], [5.6125, 5, 5] ], cell=[30,30,30], pbc=True)
    atoms_init.positions[2,0] = atoms_init.positions[2, 0]+d
    atoms_init.positions[3,0] = atoms_init.positions[3, 0]+d
    atoms=atoms_init.copy()
    atoms_list.append(atoms.copy())

###################
######## o ########
#### o-o | ########
######## o ########
###################
for i in range(nsteps):
    d = 1.4 + i * step
    #d = step
    atoms_init = Atoms('O4', positions=[[5, 5, 4.3875], [5, 5, 5.6125],[4.3875, 5, 5], [5.6125, 5, 5] ], cell=[30,30,30], pbc=True)
    atoms_init.positions[2,0] = atoms_init.positions[2, 0]+d
    atoms_init.positions[3,0] = atoms_init.positions[3, 0]+d
    atoms=atoms_init.copy()
    atoms_list.append(atoms.copy())




#view(atoms_list, viewer='ngl')

# %%
en_list = []
di_list=[]
fo_list=[]
atoms_list=[]

#atoms_init = Atoms('O4', positions=[[5, 5, 5], [5, 5, 6.225],[6, 5, 5], [6, 5, 6.225] ], cell=[30,30,30], pbc=True)

step = 0.2
nsteps = 20
for i in range(nsteps):
    ###################
    ### change this ###
    ###################
    
    d = 1.2 + i * step
    #d = step
    atoms_init = Atoms('O4', positions=[[5, 5, 4.3875], [5, 5, 5.6125],[5, 4.3875, 5], [5, 5.6125, 5] ], cell=[30,30,30], pbc=True)
    atoms_init.positions[2,0] = atoms_init.positions[2, 0]+d
    atoms_init.positions[3,0] = atoms_init.positions[3, 0]+d
    atoms=atoms_init.copy()
    atoms.set_calculator(calc)
    atoms_list.append(atoms.copy())
    
    ###################
    ###################
    ###################
    
    
    en_list.append(atoms.get_potential_energy())
    di_list.append(d)


plt.plot(di_list, en_list)

# %% [markdown]
# ## Li2O

# %%
strucs=['li2o']

alat_list=[]
energy_corr_list=[]

for struc in strucs:
    test_dir = f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/{struc}/fit/"
    x = []
    xd = []
    y = []
    yd = []
    dummy1=[]
    x_ref = []
    y_ref = []


######   
    for file in os.listdir(test_dir):
        fpath = os.path.join(test_dir, file)
        
        if fnmatch.fnmatch(file, 'OUT*'):
            structure = read(fpath, format = 'espresso-out')
            structure.set_calculator(calc)
            energy = structure.get_potential_energy()
            #forces = structure.get_forces()
            #gamma = structure.get_gamma()
            elems = structure.get_chemical_symbols()
            elem_dict = Counter(elems)
            n_units = elem_dict['O']
            ref_e = (2 * ref_energies['Li'] + ref_energies['O']) * n_units
            
            corr_e = (energy + ref_e)
            energy_corr_list.append(corr_e/Rydberg)
            
            vol_per_unit = structure.get_volume() / n_units
            energy_per_unit = corr_e / n_units
            #xd.append(vol_per_unit)
            
            alat=float(file.replace('OUT.',''))
            alat_list.append(alat)
            alat_angstrom=alat*0.529177
            
            xd.append(alat_angstrom)
            yd.append(energy_per_unit)

        else:
            continue
######                    
    for k in range(len(xd)):
        dummy2=[xd[k], yd[k]]
        dummy1.append(dummy2)
    dummy1.sort(key=lambda tup: tup[0])
    for j in range(len(dummy1)):
        x.append(dummy1[j][0])
        y.append(dummy1[j][1])

    x_ref = []
    y_ref = []

    x_ref = np.loadtxt(f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/{struc}/fit/plot/out.dat", usecols=0)
    y_ref = np.loadtxt(f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/{struc}/fit/plot/out.dat", usecols=1)

    #E_diff= y-y_ref
    
    #x_ref.append(x_ref0)
    #y_ref.append(y_ref0)
    #plt.title(f"{struc}")
    plt.plot(x, y_ref, label = f"{struc}",linewidth=2)
    plt.plot(x, y,'k:', linewidth=1.8, color='green', label = pot_name)
    #plt.xlabel("Volume per Li$_2$O unit / $\AA ^3$")
    plt.xlabel("Lattice constant / $\AA $")
    plt.ylabel("Energy per Li$_2$O unit / eV")
    plt.legend()
    plt.ylim((-830.84, -830.8))
    plt.xlim((4.5, 4.7))
    plt.ticklabel_format(axis='y', style='plain', useOffset=False)

# %% [markdown]
# ### Li2O alat

# %%
data = '/ccc160/bmeyer/work/project-battery/Li2O-bulk/fcc.pbe+D3surf-mod/elast-const/B-bulk-modulus/vol.k08/'
#alat = np.loadtxt(f"{data}", usecols = 0, skiprows=1, max_rows=14)
#PE = np.loadtxt(f"{data}", usecols = 1, skiprows=1, max_rows=14)

alat_list=[]
energy_corr_list=[]

for file in os.listdir(data):
    fpath = os.path.join(data, file)
        
    if fnmatch.fnmatch(file, 'OUT*'):
        structure = read(fpath, format = 'espresso-out')
        structure.set_calculator(calc)
        energy = structure.get_potential_energy()
        elems = structure.get_chemical_symbols()
        elem_dict = Counter(elems)
        ref_e = elem_dict['Li']*ref_energies['Li'] + elem_dict['O']*ref_energies['O']
            
        corr_e = (energy + ref_e)
        energy_corr_list.append(corr_e/Rydberg)
        alat=float(file.replace('OUT.',''))
        alat_list.append(alat)

fit_coef = np.polyfit(alat_list, energy_corr_list, 3) # f = coef0*x**3 + coef1*x**2 + coef2*x +coef3
fit = np.poly1d(fit_coef)

df = np.polyder(fit)    # f' -> quadratic: f' = 3*coef0x**2 + 2*coef1*x + coef2

a_df = 3*fit_coef[0]
b_df = 2*fit_coef[1]
c_df = fit_coef[2]

disc_df = np.sqrt(b_df**2 - 4*a_df*c_df)

x_1 = (-b_df + disc_df)/(2*a_df) # extremum 1 of fit
y_1 = fit(x_1)
x_2 = (-b_df - disc_df)/(2*a_df) # extremum 2 of fit
y_2 = fit(x_2)

ddf = np.polyder(df)  # f'' -> linear:   f''= 6*coef0*x + 2*coef1
ddfit = np.poly1d(ddf)

bmod_1 = ddfit(x_1)*0.5  # bmod from Bernds script, 0.5*(d^2 E/ d a^2 |_a0)
bmod_2 = ddfit(x_2)*0.5

B_1 = (2*bmod_1)/(9*x_1)*1.47108*10**4 # B in GPa
B_2 = (2*bmod_2)/(9*x_2)*1.47108*10**4

print(f"Extrema 1: x = {x_1}, y = {y_1}, bmod = {bmod_1}, B = {B_1}")
print(f"Extrema 2: x = {x_2}, y = {y_2}, bmod = {bmod_2}, B = {B_2}")

print(f"Lattice constant = {x_1*0.529177} Angstrom")

# %% [markdown]
# ## Li-Metal

# %%
#strucs=[ 'bcc', 'fcc', 'cubicP']
strucs=['bcc']

for struc in strucs:
    test_dir = f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/li-metal/{struc}/fit/"
    x = []
    xd = []
    y = []
    y_2 = []
    yd = []
    yd_2 = []
    dummy1=[]
    x_ref = []
    y_ref = []

######   
    for file in os.listdir(test_dir):
        fpath = os.path.join(test_dir, file)
        
        if fnmatch.fnmatch(file, 'OUT*'):
            structure = read(fpath, format = 'espresso-out')
            structure.set_calculator(calc)
            energy = structure.get_potential_energy()
            #forces = structure.get_forces()
            #gamma = structure.get_gamma()
            elems = structure.get_chemical_symbols()
            elem_dict = Counter(elems)
            n_units = elem_dict['Li']
            ref_e = ref_energies['Li'] * n_units
            corr_e = (energy + ref_e)
            vol_per_unit = structure.get_volume() / n_units
            energy_per_unit = corr_e / n_units
            alat=float(file.replace('OUT.',''))
            alat_angstrom=alat*0.529177
            
            xd.append(alat_angstrom)
            yd.append(energy_per_unit)
            #print(alat, energy)
        else:
            continue
######                    
    for k in range(len(xd)):
        dummy2=[xd[k], yd[k]]
        dummy1.append(dummy2)
    dummy1.sort(key=lambda tup: tup[0])
    for j in range(len(dummy1)):
        x.append(dummy1[j][0])
        y.append(dummy1[j][1])

    x_ref = []
    y_ref = []

    x_ref = np.loadtxt(f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/li-metal/{struc}/fit/plot/out.dat", usecols=0)
    y_ref = np.loadtxt(f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/li-metal/{struc}/fit/plot/out.dat", usecols=1)

    #E_diff= y-y_ref
    
    y_arr = np.array(y)
    
    plt.plot(x, y_ref, label = "Li-metal bcc",linewidth=2)
    plt.plot(x, y_arr,'k:', linewidth=1.8, color='green', label = pot_name)
    plt.ylim((-195.346, -195.33))
    plt.xlim((3.35, 3.5))
    plt.xlabel("Lattice constant / $\AA $")
    plt.ylabel("Energy per Li atom / eV")
    plt.legend()
    plt.ticklabel_format(axis='y', style='plain', useOffset=False)
    plt.tight_layout()

# %%
#strucs=[ 'bcc', 'fcc', 'cubicP']
strucs=['fcc']

for struc in strucs:
    test_dir = f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/li-metal/{struc}/fit/"
    x = []
    xd = []
    y = []
    y_2 = []
    yd = []
    yd_2 = []
    dummy1=[]
    x_ref = []
    y_ref = []

######   
    for file in os.listdir(test_dir):
        fpath = os.path.join(test_dir, file)
        
        if fnmatch.fnmatch(file, 'OUT*'):
            structure = read(fpath, format = 'espresso-out')
            structure.set_calculator(calc)
            energy = structure.get_potential_energy()
            #forces = structure.get_forces()
            #gamma = structure.get_gamma()
            elems = structure.get_chemical_symbols()
            elem_dict = Counter(elems)
            n_units = elem_dict['Li']
            ref_e = ref_energies['Li'] * n_units
            corr_e = (energy + ref_e)
            vol_per_unit = structure.get_volume() / n_units
            energy_per_unit = corr_e / n_units
            alat=float(file.replace('OUT.',''))
            alat_angstrom=alat*0.529177
            
            xd.append(alat_angstrom)
            yd.append(energy_per_unit)
            #print(alat, energy)
        else:
            continue
######                    
    for k in range(len(xd)):
        dummy2=[xd[k], yd[k]]
        dummy1.append(dummy2)
    dummy1.sort(key=lambda tup: tup[0])
    for j in range(len(dummy1)):
        x.append(dummy1[j][0])
        y.append(dummy1[j][1])

    x_ref = []
    y_ref = []

    x_ref = np.loadtxt(f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/li-metal/{struc}/fit/plot/out.dat", usecols=0)
    y_ref = np.loadtxt(f"/ccc160/akirsan/PhD/MLP/Li2O/binding-curves/li-metal/{struc}/fit/plot/out.dat", usecols=1)

    #E_diff= y-y_ref
    
    y_arr = np.array(y)
    
    plt.plot(x, y_ref, label = "Li-metal bcc",linewidth=2)
    plt.plot(x, y_arr,'k:', linewidth=1.8, color='green', label = pot_name)
    plt.ylim((-195.350, -195.335))
    plt.xlim((4.2, 4.4))
    plt.xlabel("Lattice constant / $\AA $")
    plt.ylabel("Energy per Li atom / eV")
    plt.legend()
    plt.ticklabel_format(axis='y', style='plain', useOffset=False)
    plt.tight_layout()

# %% [markdown]
# # MISC

# %%
scfs_dir = '/ccc160/akirsan/PhD/MLP/Li2O/str-gen/O2/own/monomer'

for i in range(len(atoms_list)):
    struc = atoms_list[i]
    #struc.wrap()
    input_data = {
                    'calculation' : 'scf',
                    'restart_mode' : 'from_scratch',
                    'pseudo_dir' : '/ccc160/bmeyer/pot.pwscf/',
                    'outdir' : './',
                    'prefix' : f"str_monomer_{i}",
                    'etot_conv_thr' : 1.e-5,
                    'tprnfor' : True,
                    'forc_conv_thr' : 1.e-5,
                    'ecutwfc' :30.0,
                    'ecutrho' :120.0,
                    'occupations' : 'smearing',
                    'mixing_mode' : 'plain',
                    'smearing' : 'gauss',
                    'degauss' : 0.01,
                    'vdw_corr' : 'D3-ext',
                    'london_rcut' : 100,
                    'diagonalization' : 'david',
                    'electron_maxstep' : 300,
                    'conv_thr' :1.0e-7,
                    'mixing_beta' : 0.2,
                    'kpts' : (1, 1, 1),
                    'koffset' : (0, 0, 0),
                    }
                
    pseudopotentials = {
                    'O' : 'O.uspp736.pbe.UPF',
                    }

    scf_dir = os.path.join(scfs_dir, f"str_monomer_{i}")
    input_file_path = os.path.join(scf_dir, "INP")
    run(f"mkdir {scf_dir}")

                
    with open(input_file_path, mode = 'w') as f:
                write(f, struc, format  = 'espresso-in', input_data=input_data, \
                pseudopotentials=pseudopotentials,\
                kpts=input_data['kpts'], koffset=input_data['koffset'])

# %%
scfs_dir='/ccc160/akirsan/PhD/MLP/Li2O/str-gen/O2/own/cpmd/scfs-trimer'

traj_path = '/ccc160/akirsan/PhD/MLP/Li2O/str-gen/O2/own/cpmd/4.md/trimer/'
setup = traj_path.replace("/ccc160/akirsan/PhD/MLP/Li2O/str-gen/O2/own/cpmd/4.md/", "")
setup = setup.replace('/','_')
setup = setup.rstrip("_")
traj = read(os.path.join(traj_path,'TRAJEC.xyz'), format ='xyz', index="::10")

i=0
for struc in traj:
    i=i+1
    struc.set_pbc(True)
    struc.set_cell([7.5,7.5,7.5])
    struc.wrap()
    input_data = {
                    'calculation' : 'scf',
                    'restart_mode' : 'from_scratch',
                    'pseudo_dir' : '/ccc160/bmeyer/pot.pwscf/',
                    'outdir' : './',
                    'prefix' : f"{setup}_{i}",
                    'etot_conv_thr' : 1.e-5,
                    'tprnfor' : True,
                    'forc_conv_thr' : 1.e-5,
                    'ecutwfc' :30.0,
                    'ecutrho' :120.0,
                    'occupations' : 'smearing',
                    'mixing_mode' : 'plain',
                    'smearing' : 'gauss',
                    'degauss' : 0.01,
                    'vdw_corr' : 'D3-ext',
                    'london_rcut' : 100,
                    'diagonalization' : 'david',
                    'electron_maxstep' : 300,
                    'conv_thr' :1.0e-7,
                    'mixing_beta' : 0.2,
                    'kpts' : (1, 1, 1),
                    'koffset' : (0, 0, 0),
                    }
                
    pseudopotentials = {
                    'O' : 'O.uspp736.pbe.UPF',
                    }

    scf_dir = os.path.join(scfs_dir, f"{setup}_{i}")
    input_file_path = os.path.join(scf_dir, "INP")
    run(f"mkdir {scf_dir}")

                
    with open(input_file_path, mode = 'w') as f:
                write(f, struc, format  = 'espresso-in', input_data=input_data, \
                pseudopotentials=pseudopotentials,\
                kpts=input_data['kpts'], koffset=input_data['koffset'])

# %% [markdown]
# # Energy + strain curve graph

# %%
strain_energy = np.loadtxt('/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/elastic/strain-stress/C11/no-relax/result.out')
strain_stress = np.loadtxt('/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O-pwscf/elastic/strain-stress/C11/no-relax/strain-stress.dat')



fit_coef_stress = np.polyfit(strain_stress[:,0], strain_stress[:,1], 5)
fit_stress = np.poly1d(fit_coef_stress)
y_stress=fit_stress(x_ddf)

fit_coef_energy = np.polyfit(strain_energy[:,0], strain_energy[:,1], 4)
fit_energy = np.poly1d(fit_coef_energy)

df_energy = np.polyder(fit_energy)   
ddf_energy = np.polyder(df_energy)

x_ddf = np.linspace(-0.05, 0.05, 500)
y_df = df_energy(x_ddf)
y_ddf = ddf_energy(x_ddf)

y_energy_fit = fit_energy(x_ddf)

fig = plt.figure(figsize=(5,5))
ax = fig.subplots()
ax.ticklabel_format(axis='y', style='plain', useOffset=False)
#ax.ticklabel_format(axis='x', style='plain', useOffset=False)
ax.legend()
ax.set_xlim(-0.02, 0.02)
ax.set_ylim(-0.0003, 0.0003)
ax.plot(x_ddf, 1/659.8436*y_df, label='df')
ax.plot(x_ddf, -y_stress, label='stress-fit')
ax.scatter(strain_stress[:,0], -strain_stress[:,1], label='strain/stress', color='orange')
#ax.plot(x_ddf, y_energy_fit, label='ddf')
ax.legend()
plt.show()
# Out:
# /tmp/ipykernel_22496/696877130.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
fit_coef_energy
# Out:
# array([ 4.09663237e+01, -5.46819245e+00,  4.51455095e+00, -3.06733785e-04,
#        -2.44259226e+02])

# %%
# Li2O2 c13


strain_energy = np.loadtxt('/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O2-pwscf/elastic/C33/result.out')
strain_stress = np.loadtxt('/ccc160/akirsan/PhD/MLP/Li2O/ref-energies/Li2O2-pwscf/elastic/C13/strain-stress.dat') # for C13


fit_coef_stress = np.polyfit(strain_stress[:,0], strain_stress[:,1], 1) # for C13
fit_stress = np.poly1d(fit_coef_stress) # for C13




for i in range(len(strain_energy)):
    strain_energy[i][0] = 1-(strain_energy[i][0]/2.4335)


fit_coef_energy = np.polyfit(strain_energy[:,0], strain_energy[:,1], 2)
fit_energy = np.poly1d(fit_coef_energy)

df_energy = np.polyder(fit_energy)   
ddf_energy = np.polyder(df_energy)

x_plot = np.linspace(-0.06, 0.06, 500)
y_energy_fit = fit_energy(x_plot)
y_df = df_energy(x_plot)
y_ddf = ddf_energy(x_plot)
y_stress=fit_stress(x_plot) # for C13


fig = plt.figure(figsize=(5,5))
ax = fig.subplots()
ax.ticklabel_format(axis='y', style='plain', useOffset=False)

ax.legend()
#ax.set_xlim(-0.02, 0.02)
#ax.set_ylim(-0.0003, 0.0003)

#ax.plot(x_plot, 1/441.6269*y_df, label='df')
#ax.plot(x_plot, y_energy_fit, label='energy-fit')

ax.plot(x_plot, y_stress, label='stress-fit') # for C13
ax.scatter(strain_stress[:,0], strain_stress[:,1], label='stress-data', color='orange') # for C13

ax.legend()
plt.show()
# Out:
# /tmp/ipykernel_22496/2737984299.py:35: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
#(fit_coef_energy[0]*2)/441.6269 * Ry_bohr3_to_GPa
-fit_coef_stress[0]* Ry_bohr3_to_GPa
# Out:
# 10.362222857142857

# %% [markdown]
# # TEST

# %%
structure = Structure.from_ase_atoms(bulk_strucs_dict['Li2O2']['ase_atoms'])
sga = SpacegroupAnalyzer(structure)
conventional = sga.get_conventional_standard_structure() # convert structure to conventional cell
slabgen = SlabGenerator(
conventional,
miller_index=(0, 0, 1),
min_slab_size=2,
min_vacuum_size=1,
center_slab=False,
in_unit_planes = True,
 max_normal_search = 1
)
slabs = slabgen.get_slabs()
slab = slabs[0]
surf = slab.to_ase_atoms()
surf.center(vacuum=0, axis=2)
#surf = surf.repeat((2, 2, 1))

surf.calc=calc
surfs_atoms=[]
energies = []
write('/ccc160/akirsan/PhD/struc.dat', surf, format = 'lammps-data', masses=True)

# %%
layers = get_layers(surf)
match=find_matching_layers(surf, layers)
z = len(layers) * match[1] / match[0]
surf=surf.repeat((2,2,1))
vac = 15
cell = surf.cell
cell[2] = cell[2] / np.linalg.norm(cell[2]) * (z+vac)
surf.set_cell(cell)

# %% [markdown]
# # INSPECT FUNCTIONS

# %%
import inspect
lines = inspect.getsource(find_stable_surface())
print(lines)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[235], line 2
#       1 import inspect
# ----> 2 lines = inspect.getsource(find_stable_surface())
#       3 print(lines)
#
# TypeError: find_stable_surface() missing 5 required positional arguments: 'atoms', 'h', 'k', 'l', and 'nrep'

# %%
lines = inspect.getsource(spg.get_symmetry_dataset)
print(lines)
# Out:
# def get_symmetry_dataset(
#     cell: Cell,
#     symprec=1e-5,
#     angle_tolerance=-1.0,
#     hall_number=0,
# ) -> SpglibDataset | None:
#     """Search symmetry dataset from an input cell.
#
#     Parameters
#     ----------
#     cell, symprec, angle_tolerance:
#         See :func:`get_symmetry`.
#     hall_number : int
#         If a serial number of Hall symbol (>0) is given, the database
#         corresponding to the Hall symbol is made.
#
#         The mapping from Hall symbols to a space-group-type is the many-to-one mapping.
#         Without specifying this
#         option (i.e., in the case of ``hall_number=0``), always the first one
#         (the smallest serial number corresponding to the space-group-type in
#         [list of space groups (Seto's web site)](https://yseto.net/en/sg/sg1))
#         among possible choices and settings is chosen as default. This
#         argument is useful when the other choice (or setting) is expected to
#         be hooked.
#
#         This affects to the obtained values of `international`,
#         `hall`, `choice`, `transformation_matrix`,
#         `origin shift`, `wyckoffs`, `std_lattice`, `std_positions`,
#         `std_types` and `std_rotation_matrix`, but not to `rotations`
#         and `translations` since the later set is defined with respect to
#         the basis vectors of user's input (the `cell` argument).
#
#         See also :ref:`dataset_spg_get_dataset_spacegroup_type`.
#
#     Returns
#     -------
#     dataset: :class:`SpglibDataset` | None
#         If it fails, None is returned. Otherwise a dictionary is returned.
#         More details are found at :ref:`spglib-dataset`.
#
#     """
#     _set_no_error()
#
#     lattice, positions, numbers, _ = _expand_cell(cell)
#
#     spg_ds = _spglib.dataset(
#         lattice,
#         positions,
#         numbers,
#         hall_number,
#         symprec,
#         angle_tolerance,
#     )
#     if spg_ds is None:
#         _set_error_message()
#         return None
#
#     dataset = _build_dataset_dict(spg_ds)
#     return dataset
